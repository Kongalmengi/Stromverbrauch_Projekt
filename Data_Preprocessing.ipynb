# %% [markdown]
# # 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 데이터 확인

# %% [markdown]
# ## 독일 전기 총 생산량 & 소비량 데이터
# - df_GPG : 총 생산량
# - df_GPC : 총 소비량

# %%
df_GPG = pd.read_csv('Data2/Gross_Power_Generation.csv')
df_GPG.head(2)
# Out:
#    Jahr  Generation
# 0  1990   549.63144
# 1  1991   540.29482

# %%
df_GPC = pd.read_csv('Data2/Gross_Power_Consumption.csv')
df_GPC.head(2)
# Out:
#    Jahr  Consumption
# 0  1990    550.61423
# 1  1991    539.80343
